# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import healpy as hp
import numpy as np
import tensorflow as tf

from deepsphere import HealpyGCNN
from deepsphere import healpy_layers as hp_layer
from deepsphere import utils

from tqdm import tqdm
# Out:
# 2022-06-18 20:52:07.562085: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
import os

# %%
# import pyccl as ccl

# cosmo = ccl.Cosmology(Omega_c = 0.262, Omega_b = 0.048, h = 0.69, sigma8 = 0.83, n_s = 0.96)

# zs=np.linspace(0,1,100)
# dNdz = np.ones(zs.shape)
# bias = 1*np.ones(len(dNdz))

# clustering = ccl.NumberCountsTracer(cosmo, has_rsd=False, dndz=(zs,dNdz), bias=(zs,bias))
# ell = np.arange(0,6144)
# cls_clu = ccl.angular_cl(cosmo, clustering, clustering, ell) #Clustering

# %%
kSZMap = hp.read_map("./kSZ_NS_2048_R_2048_P_2560_DV_256.fits")
kSZMap2 = hp.read_map("./lensedkSZ_NS_1024_R_2968_P_2048_DV_80.fits")
kSZMap3 = np.load("./_NS_64_R_2968_P_192_DV_40_Sd_170351.npy")
kSZMap4 = np.load("./_NS_64_R_1484_P_256_DV_40_Sd_968694.npy")
kSZMap5 = np.load("./_NS_64_R_371_P_256_DV_40_Sd_868897.npy")
kSZMap6 = np.load("./_NS_64_R_2968_P_1024_DV_40_Sd_396025.npy")

# %%
#2560^2 Particles
plt.hist(kSZMap, bins=np.linspace(-10**-5,10**-5));

# %%
#2048^2 particles
plt.hist(kSZMap2, bins=np.linspace(-10**-5,10**-5));

# %%
#192 particles, 
plt.hist(kSZMap3, bins=np.linspace(-10**-5,10**-5));

# %%
#256 particles, 
plt.hist(kSZMap4, bins=np.linspace(-10**-5,10**-5));

# %%
#256 particles, 
plt.hist(kSZMap5, bins=np.linspace(-10**-5,10**-5));

# %%
#1024 particles 
plt.hist(kSZMap6, bins=np.linspace(-10**-5,10**-5));

# %%
#192^2 particles
plt.hist(kSZData[2], bins=np.linspace(-10**-5,10**-5));

# %%
hp.mollview(kSZMap2,max=8*10**-6,min=-8*10**-6)

# %%
hp.mollview(kSZData[2],max=2*10**-6,min=-2*10**-6,nest=True)

# %%
kSZFiles = os.listdir('./Data/kSZ')
velFiles = os.listdir('./Data/velocityField')
densFiles = os.listdir('./Data/overdensity')

nside = 64
numSets=len(densFiles)

# %%
overdensData = np.zeros((numSets,12*nside**2))
kSZData = np.zeros((numSets,12*nside**2))
velData = np.zeros((numSets,12*nside**2))

# %%
for i in range(0,numSets):
    overdensData[i] = hp.reorder(np.load('./Data/overdensity/'+densFiles[i]),r2n=True)
#     overdensData[i] = 100*overdensData[i]/np.linalg.norm(overdensData[i])
    kSZData[i] = hp.reorder(np.load('./Data/kSZ/'+kSZFiles[i]),r2n=True)
#     kSZData[i] = 100*kSZData[i]/np.linalg.norm(kSZData[i])
    velData[i] = hp.reorder(np.load('./Data/velocityField/'+velFiles[i]),r2n=True)
#     velData[i] = 100*velData[i]/np.linalg.norm(velData[i])
# for i in range(0,numSets):
#     overdensData[i] = hp.reorder(hp.synfast(cls_clu,nside=nside),r2n=True)
#     kSZData[i] = hp.reorder(100000*hp.synfast(kSZPowSpec,nside=nside),r2n=True)
#     velData[i] = hp.reorder(kSZData[i]/(overdensData[i]+1),r2n=True)

# %%
plt.hist(kSZData[2], bins=np.linspace(-10**-5,10**-5));

# %%
#Make Fake CMB
h=0.69
pars = camb.CAMBparams()
pars.set_cosmology(H0=100.0*h, ombh2=0.048*h**2, omch2=0.262*h**2, mnu=0.06, omk=0)
pars.InitPower.set_params(As=2e-9, ns=0.96, r=0)
pars.set_for_lmax(6144, lens_potential_accuracy=0)
results = camb.get_results(pars)
powers =results.get_cmb_power_spectra(pars, CMB_unit='K')
l=np.arange(0,len(powers['total'][:,0]))
cambFactor = l*(l+1)/(2*np.pi)
CMB_camb = powers['total'][:,0]/cambFactor
CMB_camb[0]=0.0

# %%
CMB_map = hp.sphtfunc.synfast(CMB_camb,nside=nside);

# %%
x_raw = np.stack((overdensData,kSZData),axis=2)
x_raw = np.reshape(x_raw,(numSets,12*nside**2,2))

x_train, x_test = np.split(x_raw, indices_or_sections=[numSets-numSets//20])
y_train, y_test = np.split(velData, indices_or_sections=[numSets-numSets//20])

# %%
dset_test = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_test),
                                 tf.data.Dataset.from_tensor_slices(y_test)))
dset_test = dset_test.shuffle(20)
dset_test = dset_test.batch(8)

dset_train = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_train),
                                  tf.data.Dataset.from_tensor_slices(y_train)))
dset_train = dset_train.shuffle(200)
dset_train = dset_train.batch(8)
# Out:
# 2022-06-03 20:52:12.162819: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:12.215609: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:12.215911: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:12.217716: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-03 20:52:12.219988: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:12.220252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:12.220586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:13.120625: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:13.121306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:13.121336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-06-03 20:52:13.121913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:961] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-06-03 20:52:13.121993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5446 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
AUTOTUNE = tf.data.AUTOTUNE

dset_train = dset_train.prefetch(buffer_size=AUTOTUNE)
dset_test = dset_test.prefetch(buffer_size=AUTOTUNE)

# %%
hp.mollview(overdensData[350],nest=True)
# Out:
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_over(newcm(1.0))
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_under(bgcolor)
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:922: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_bad(badcolor)
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(

# %%
hp.mollview(kSZData[350],nest=True,max=10**-6,min=-10**-6)

# %%
hp.mollview(velData[350],nest=True)

# %%
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
K = 5
layersBest = [#hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=64, activation="linear"),
                  tf.keras.layers.BatchNormalization(),
                  hp_layer.HealpyChebyshev(K=K, Fout=64, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="linear"),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=16, activation="elu"),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="linear"),
                  hp_layer.HealpyMonomial(K=K, Fout=32, use_bias=True, use_bn=False, 
                                           activation="linear"),
                  hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="linear"),
                  #tf.keras.layers.BatchNormalization(),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
                                   activation="linear"),
#                   hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
#                                    activation="linear"),
                  #tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
                                           activation="linear"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  #hp_layer.HealpyPool(p=1,pool_type='MAX'),
                  hp_layer.HealpyMonomial(K=K, Fout=32, use_bias=True, use_bn=False, 
                                           activation="linear"),
                  hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=32, activation="linear"),
                  #tf.keras.layers.LayerNormalization(axis=1),
                  #hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=16, activation="elu"),
                  #hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=16, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  #tf.keras.layers.Dense(12*nside**2)
                  #hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=24, activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=24, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                           activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=8, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=1, use_bias=True, use_bn=False, 
                                   activation="linear")
         ]

layersTest = [#hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=64, activation="linear"),
                  tf.keras.layers.BatchNormalization(),
                  hp_layer.HealpyChebyshev(K=K, Fout=64, use_bias=True, use_bn=False, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="linear"),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=16, activation="elu"),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  #hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="linear"),
                  hp_layer.HealpyMonomial(K=K, Fout=24, use_bias=True, use_bn=True, 
                                           activation="linear"),
                  hp_layer.HealpyPseudoConv(p=1, Fout=32, activation="linear"),
                  #tf.keras.layers.BatchNormalization(),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  #tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyChebyshev(K=K, Fout=32, use_bias=True, use_bn=True, 
                                           activation="linear"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  #hp_layer.HealpyPool(p=1,pool_type='MAX'),
                  hp_layer.HealpyMonomial(K=K, Fout=32, use_bias=True, use_bn=True, 
                                           activation="linear"),
                  hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=32, activation="linear"),
                  #tf.keras.layers.LayerNormalization(axis=1),
                  #hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=16, activation="elu"),
                  #hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=16, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=24, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  #tf.keras.layers.Dense(12*nside**2)
                  #hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=24, activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=24, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=24, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=True, 
                                           activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=8, use_bias=True, use_bn=True, 
                                   activation="linear"),
                  hp_layer.HealpyChebyshev(K=K, Fout=1, use_bias=True, use_bn=True, 
                                   activation="linear")
         ]

# %%
#help(hp_layer.HealpyChebyshev)

# %%
n_pix = hp.nside2npix(nside)
indices = np.arange(n_pix)
modelHP = HealpyGCNN(nside=nside, layers=layersBest,indices=np.arange(0,12*nside**2), n_neighbors=40)
modelHP.build(input_shape=(None, len(indices), 2))
modelHP.summary(110)
# Out:
# WARNING: This network assumes that everything concerning healpy is in NEST ordering...
# Detected a reduction factor of 1.0, the input with nside 64 will be transformed to 64 during a forward pass. Checking for consistency with indices...
# indices seem consistent...
# Model: "healpy_gcnn_1"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  batch_normalization (BatchNormalization)        (None, 49152, 2)                            8
#
#  chebyshev (Chebyshev)                           (None, 49152, 64)                           704
#
#  chebyshev_1 (Chebyshev)                         (None, 49152, 32)                           10272
#
#  chebyshev_2 (Chebyshev)                         (None, 49152, 32)                           5152
#
#  layer_normalization (LayerNormalization)        (None, 49152, 32)                           98304
#
#  monomial (Monomial)                             (None, 49152, 32)                           5152
#
#  healpy_pseudo_conv (HealpyPseudoConv)           (None, 12288, 32)                           4128
#
#  chebyshev_3 (Chebyshev)                         (None, 12288, 32)                           5152
#
#  chebyshev_4 (Chebyshev)                         (None, 12288, 32)                           5152
#
#  layer_normalization_1 (LayerNormalization)      (None, 12288, 32)                           24576
#
#  monomial_1 (Monomial)                           (None, 12288, 32)                           5152
#
#  healpy_pseudo_conv__transpose (HealpyPseudoConv  (None, 49152, 32)                          4128
#  _Transpose)
#
#  chebyshev_5 (Chebyshev)                         (None, 49152, 32)                           5152
#
#  chebyshev_6 (Chebyshev)                         (None, 49152, 32)                           5152
#
#  chebyshev_7 (Chebyshev)                         (None, 49152, 24)                           3864
#
#  chebyshev_8 (Chebyshev)                         (None, 49152, 16)                           1936
#
#  chebyshev_9 (Chebyshev)                         (None, 49152, 8)                            648
#
#  chebyshev_10 (Chebyshev)                        (None, 49152, 1)                            41
#
# ==============================================================================================================
# Total params: 184,673
# Trainable params: 184,669
# Non-trainable params: 4
# ______________________________________________________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

modelHP.compile(optimizer=opt,
              #loss=tf.keras.losses.Huber(delta=1.0,reduction="auto",name="huber_loss"),
                loss="MSE",
              metrics=[r_square]
)

checkpoint_filepath = './checkpoint'

# model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
#     filepath=checkpoint_filepath+"/{epoch}",
#     save_weights_only=False,
#     monitor='loss',
#     save_freq=3
# )
filePath = "./models/Model1_weights.{epoch:02d}.hdf5"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=filePath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min')

# %%
initial_epochs = 10
history = modelHP.fit(
    dset_train,
    epochs=initial_epochs,
    validation_data = dset_test,
    callbacks=[model_checkpoint_callback]
)
# Out:
# Epoch 1/10
# 2022-06-03 20:55:10.737102: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2022-06-03 20:55:11.370864: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8400
# 2022-06-03 20:55:13.126644: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: Permission denied
# 177/177 [==============================] - 201s 1s/step - loss: 4455060.0000 - r_square: -0.0151 - val_loss: 4547027.0000 - val_r_square: -0.0078
# Epoch 2/10
# 177/177 [==============================] - 194s 1s/step - loss: 4426248.0000 - r_square: -0.0012 - val_loss: 4514209.5000 - val_r_square: 0.0116
# Epoch 3/10
# 177/177 [==============================] - 195s 1s/step - loss: 4344200.5000 - r_square: 0.0170 - val_loss: 3199984.5000 - val_r_square: 0.2581
# Epoch 4/10
# 177/177 [==============================] - 195s 1s/step - loss: 2339769.0000 - r_square: 0.4729 - val_loss: 2254325.5000 - val_r_square: 0.4702
# Epoch 5/10
# 177/177 [==============================] - 195s 1s/step - loss: 2137636.2500 - r_square: 0.5198 - val_loss: 2232018.5000 - val_r_square: 0.5071
# Epoch 6/10
# 177/177 [==============================] - 195s 1s/step - loss: 2114132.2500 - r_square: 0.5290 - val_loss: 2218460.5000 - val_r_square: 0.5035
# Epoch 7/10
# 177/177 [==============================] - 195s 1s/step - loss: 2098788.2500 - r_square: 0.5291 - val_loss: 2251681.0000 - val_r_square: 0.5243
# Epoch 8/10
# 177/177 [==============================] - 195s 1s/step - loss: 2080081.6250 - r_square: 0.5382 - val_loss: 2233426.2500 - val_r_square: 0.5301
# Epoch 9/10
# 177/177 [==============================] - 195s 1s/step - loss: 2072860.8750 - r_square: 0.5342 - val_loss: 2202350.0000 - val_r_square: 0.4991
# Epoch 10/10
# 177/177 [==============================] - 195s 1s/step - loss: 2037791.8750 - r_square: 0.5403 - val_loss: 2250285.2500 - val_r_square: 0.5028

# %%
fine_tune_epochs = 2
total_epochs =  initial_epochs + fine_tune_epochs

history_further = modelHP.fit(dset_train,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=dset_test)
# Out:
# Epoch 10/12
# 177/177 [==============================] - 195s 1s/step - loss: 1945136.1250 - r_square: 0.5650 - val_loss: 2371053.5000 - val_r_square: 0.5076
# Epoch 11/12
# 177/177 [==============================] - 195s 1s/step - loss: 1750159.7500 - r_square: 0.6088 - val_loss: 2424637.7500 - val_r_square: 0.4759
# Epoch 12/12
# 177/177 [==============================] - 194s 1s/step - loss: 1502733.3750 - r_square: 0.6614 - val_loss: 2997221.5000 - val_r_square: 0.3576

# %%
total_epochs =  initial_epochs + fine_tune_epochs+1

history_furthest = modelHP.fit(dset_train,
                         epochs=total_epochs,
                         initial_epoch=history_further.epoch[-1],
                         validation_data=dset_test)
# Out:
# Epoch 12/13
# 177/177 [==============================] - 195s 1s/step - loss: 1269861.1250 - r_square: 0.7099 - val_loss: 2742601.2500 - val_r_square: 0.3871
# Epoch 13/13
# 177/177 [==============================] - 195s 1s/step - loss: 1107874.1250 - r_square: 0.7464 - val_loss: 2709656.5000 - val_r_square: 0.3971

# %%
total_epochs =  initial_epochs + fine_tune_epochs+1+1

history_furthester = modelHP.fit(dset_train,
                         epochs=total_epochs,
                         initial_epoch=history_furthest.epoch[-1],
                         validation_data=dset_test)
# Out:
# Epoch 13/14
# 177/177 [==============================] - 195s 1s/step - loss: 1003034.1875 - r_square: 0.7708 - val_loss: 2981258.5000 - val_r_square: 0.3459
# Epoch 14/14
# 177/177 [==============================] - 194s 1s/step - loss: 942393.5000 - r_square: 0.7827 - val_loss: 3067924.0000 - val_r_square: 0.3119

# %%
#modelHP.save('SavedModels/BestModelSoFar/')

# %%
reconst = np.reshape(modelHP(x_train[10:11],True).numpy(),(12*nside**2))
goal = np.reshape(y_train[10:11],(12*nside**2))

# %%
hp.mollview(goal, nest=True, title="Goal Map");
hp.mollview(reconst, nest=True, title="Reconstruction Map");
hp.mollview(reconst - goal, nest=True, title="Difference");
# Out:
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_over(newcm(1.0))
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_under(bgcolor)
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:922: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_bad(badcolor)
# /home/wurdahl/anaconda3/lib/python3.9/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(

# %%
reconst = hp.reorder(reconst,n2r=True)
goal = hp.reorder(goal,n2r=True)
plt.loglog(hp.anafast(reconst))
plt.loglog(hp.anafast(goal))
plt.legend(["Reconstructed","Actual"])

# %%
correlation = hp.anafast(reconst,goal)/np.sqrt(hp.anafast(goal)*hp.anafast(reconst))

# %%
plt.semilogx(correlation);
plt.grid()
plt.ylim([0, 1]);

# %%
np.mean(correlation)
# Out:
# 0.17257136354201108

# %%
plt.semilogy(np.concatenate((history.history['loss'],history_further.history['loss'],history_furthest.history['loss'])), label='loss');
plt.semilogy(np.concatenate((history.history['val_loss'],history_further.history['val_loss'],history_furthest.history['val_loss'])), label = 'val_loss');
plt.xlabel('Epoch')
plt.ylabel('loss')
#plt.ylim([0.5, 1])
plt.legend(loc='upper right');

# %%
plt.semilogy(np.append(np.append(history.history['r_square'],history_further.history['r_square']),history_furthest.history['r_square']), label='r_square')
plt.semilogy(np.append(np.append(history.history['val_r_square'],history_further.history['val_r_square']),history_furthest.history['val_r_square']), label = 'val_r_square')
plt.xlabel('Epoch')
plt.ylabel('loss')
#plt.ylim([0.5, 1])
plt.legend(loc='upper right')

# %% [markdown]
# # Correlation of all samples

# %%
reconstAll = np.reshape(modelHP(x_train,False).numpy(),(12*nside**2))
goal = np.reshape(y_train,(12*nside**2))
# Out:
# 2022-06-03 21:52:16.095216: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.03GiB (rounded to 1109655552)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-06-03 21:52:16.095469: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] BFCAllocator dump for GPU_0_bfc
# 2022-06-03 21:52:16.095497: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (256): 	Total Chunks: 132, Chunks in use: 131. 33.0KiB allocated for chunks. 32.8KiB in use in bin. 6.1KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095503: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (512): 	Total Chunks: 1, Chunks in use: 0. 768B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-03 21:52:16.095506: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095510: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2048): 	Total Chunks: 5, Chunks in use: 5. 12.5KiB allocated for chunks. 12.5KiB in use in bin. 12.5KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095513: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4096): 	Total Chunks: 4, Chunks in use: 4. 26.8KiB allocated for chunks. 26.8KiB in use in bin. 25.0KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095516: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8192): 	Total Chunks: 3, Chunks in use: 3. 45.0KiB allocated for chunks. 45.0KiB in use in bin. 45.0KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095519: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16384): 	Total Chunks: 27, Chunks in use: 27. 518.0KiB allocated for chunks. 518.0KiB in use in bin. 516.0KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095522: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (32768): 	Total Chunks: 9, Chunks in use: 9. 408.0KiB allocated for chunks. 408.0KiB in use in bin. 408.0KiB client-requested in use in bin.
# 2022-06-03 21:52:16.095524: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-03 21:52:16.095527: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (131072): 	Total Chunks: 6, Chunks in use: 6. 1.12MiB allocated for chunks. 1.12MiB in use in bin. 1.12MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095530: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-03 21:52:16.095533: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-03 21:52:16.095580: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1048576): 	Total Chunks: 1, Chunks in use: 1. 1.94MiB allocated for chunks. 1.94MiB in use in bin. 1.94MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095583: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2097152): 	Total Chunks: 3, Chunks in use: 2. 9.62MiB allocated for chunks. 7.21MiB in use in bin. 3.88MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095586: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4194304): 	Total Chunks: 13, Chunks in use: 11. 98.71MiB allocated for chunks. 85.28MiB in use in bin. 85.25MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095589: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8388608): 	Total Chunks: 5, Chunks in use: 2. 77.47MiB allocated for chunks. 30.99MiB in use in bin. 15.51MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095595: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16777216): 	Total Chunks: 12, Chunks in use: 11. 356.92MiB allocated for chunks. 337.62MiB in use in bin. 337.62MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095599: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (33554432): 	Total Chunks: 3, Chunks in use: 1. 140.69MiB allocated for chunks. 55.50MiB in use in bin. 55.50MiB client-requested in use in bin.
# 2022-06-03 21:52:16.095602: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-03 21:52:16.095604: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-03 21:52:16.095607: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (268435456): 	Total Chunks: 7, Chunks in use: 5. 4.65GiB allocated for chunks. 3.62GiB in use in bin. 3.62GiB client-requested in use in bin.
# 2022-06-03 21:52:16.095941: I tensorflow/core/common_runtime/bfc_allocator.cc:1050] Bin for 1.03GiB was 256.00MiB, Chunk State:
# 2022-06-03 21:52:16.095954: I tensorflow/core/common_runtime/bfc_allocator.cc:1056]   Size: 525.87MiB | Requested Size: 30.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 529.12MiB | Requested Size: 529.12MiB | in_use: 1 | bin_num: -1
# 2022-06-03 21:52:16.095960: I tensorflow/core/common_runtime/bfc_allocator.cc:1056]   Size: 529.12MiB | Requested Size: 529.12MiB | in_use: 0 | bin_num: 20, prev:   Size: 529.12MiB | Requested Size: 529.12MiB | in_use: 1 | bin_num: -1, next:   Size: 529.12MiB | Requested Size: 529.12MiB | in_use: 1 | bin_num: -1
# 2022-06-03 21:52:16.095963: I tensorflow/core/common_runtime/bfc_allocator.cc:1063] Next region of size 5710938112
# 2022-06-03 21:52:16.096243: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 612500000 of size 58195968 next 1
# 2022-06-03 21:52:16.096249: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 615c80000 of size 1280 next 2
# 2022-06-03 21:52:16.096252: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 615c80500 of size 29097984 next 3
# 2022-06-03 21:52:16.096255: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 617840500 of size 256 next 4
# 2022-06-03 21:52:16.096257: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 617840600 of size 256 next 5
# 2022-06-03 21:52:16.096259: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 617840700 of size 256 next 6
# 2022-06-03 21:52:16.096261: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 617840800 of size 256 next 7
# 2022-06-03 21:52:16.096264: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 617840900 of size 110
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_551/1554459995.py in <module>
# ----> 1 reconstAll = np.reshape(modelHP(x_train,False).numpy(),(12*nside**2))
#       2 goal = np.reshape(y_train,(12*nside**2))
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# 9655552 next 8
# 2022-06-03 21:52:16.096267: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 659a80900 of size 554827776 next 9
# 2022-06-03 21:52:16.096269: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0900 of size 256 next 10
# 2022-06-03 21:52:16.096271: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0a00 of size 256 next 11
# 2022-06-03 21:52:16.096273: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0b00 of size 256 next 34
# 2022-06-03 21:52:16.096275: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0c00 of size 256 next 38
# 2022-06-03 21:52:16.096277: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0d00 of size 256 next 43
# 2022-06-03 21:52:16.096279: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0e00 of size 256 next 46
# 2022-06-03 21:52:16.096281: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba0f00 of size 256 next 49
# 2022-06-03 21:52:16.096284: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1000 of size 256 next 52
# 2022-06-03 21:52:16.096286: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1100 of size 256 next 55
# 2022-06-03 21:52:16.096288: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1200 of size 256 next 58
# 2022-06-03 21:52:16.096289: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1300 of size 256 next 59
# 2022-06-03 21:52:16.096291: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1400 of size 256 next 60
# 2022-06-03 21:52:16.096293: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1500 of size 256 next 61
# 2022-06-03 21:52:16.096295: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1600 of size 256 next 62
# 2022-06-03 21:52:16.096297: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1700 of size 256 next 63
# 2022-06-03 21:52:16.096299: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1800 of size 256 next 64
# 2022-06-03 21:52:16.096301: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1900 of size 256 next 65
# 2022-06-03 21:52:16.096303: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1a00 of size 256 next 66
# 2022-06-03 21:52:16.096305: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1b00 of size 256 next 69
# 2022-06-03 21:52:16.096307: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1c00 of size 256 next 70
# 2022-06-03 21:52:16.096308: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1d00 of size 256 next 71
# 2022-06-03 21:52:16.096310: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1e00 of size 256 next 72
# 2022-06-03 21:52:16.096312: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba1f00 of size 256 next 75
# 2022-06-03 21:52:16.096314: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2000 of size 256 next 76
# 2022-06-03 21:52:16.096316: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2100 of size 256 next 77
# 2022-06-03 21:52:16.096318: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2200 of size 256 next 79
# 2022-06-03 21:52:16.096320: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2300 of size 256 next 82
# 2022-06-03 21:52:16.096322: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2400 of size 256 next 85
# 2022-06-03 21:52:16.096323: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2500 of size 256 next 86
# 2022-06-03 21:52:16.096325: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2600 of size 256 next 88
# 2022-06-03 21:52:16.096327: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2700 of size 256 next 90
# 2022-06-03 21:52:16.096329: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2800 of size 256 next 92
# 2022-06-03 21:52:16.096331: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2900 of size 256 next 93
# 2022-06-03 21:52:16.096333: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2a00 of size 256 next 94
# 2022-06-03 21:52:16.096335: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2b00 of size 256 next 97
# 2022-06-03 21:52:16.096337: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2c00 of size 256 next 101
# 2022-06-03 21:52:16.096339: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2d00 of size 256 next 67
# 2022-06-03 21:52:16.096341: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba2e00 of size 2560 next 68
# 2022-06-03 21:52:16.096343: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3800 of size 256 next 102
# 2022-06-03 21:52:16.096345: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3900 of size 256 next 105
# 2022-06-03 21:52:16.096359: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3a00 of size 256 next 106
# 2022-06-03 21:52:16.096363: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3b00 of size 256 next 107
# 2022-06-03 21:52:16.096366: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3c00 of size 256 next 135
# 2022-06-03 21:52:16.096368: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3d00 of size 256 next 137
# 2022-06-03 21:52:16.096370: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3e00 of size 256 next 139
# 2022-06-03 21:52:16.096372: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba3f00 of size 256 next 143
# 2022-06-03 21:52:16.096374: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba4000 of size 18432 next 84
# 2022-06-03 21:52:16.096377: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67aba8800 of size 20480 next 80
# 2022-06-03 21:52:16.096379: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abad800 of size 20480 next 81
# 2022-06-03 21:52:16.096381: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb2800 of size 7680 next 109
# 2022-06-03 21:52:16.096383: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4600 of size 256 next 108
# 2022-06-03 21:52:16.096385: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4700 of size 256 next 110
# 2022-06-03 21:52:16.096387: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4800 of size 256 next 111
# 2022-06-03 21:52:16.096389: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4900 of size 256 next 112
# 2022-06-03 21:52:16.096391: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4a00 of size 256 next 132
# 2022-06-03 21:52:16.096393: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4b00 of size 256 next 133
# 2022-06-03 21:52:16.096395: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4c00 of size 256 next 134
# 2022-06-03 21:52:16.096397: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb4d00 of size 4352 next 115
# 2022-06-03 21:52:16.096399: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb5e00 of size 2560 next 116
# 2022-06-03 21:52:16.096401: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6800 of size 256 next 114
# 2022-06-03 21:52:16.096403: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6900 of size 256 next 117
# 2022-06-03 21:52:16.096405: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6a00 of size 256 next 118
# 2022-06-03 21:52:16.096407: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6b00 of size 256 next 119
# 2022-06-03 21:52:16.096408: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6c00 of size 256 next 120
# 2022-06-03 21:52:16.096410: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6d00 of size 256 next 121
# 2022-06-03 21:52:16.096412: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6e00 of size 256 next 122
# 2022-06-03 21:52:16.096414: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb6f00 of size 256 next 123
# 2022-06-03 21:52:16.096416: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7000 of size 256 next 124
# 2022-06-03 21:52:16.096418: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7100 of size 256 next 126
# 2022-06-03 21:52:16.096420: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7200 of size 256 next 127
# 2022-06-03 21:52:16.096422: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7300 of size 256 next 128
# 2022-06-03 21:52:16.096424: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7400 of size 256 next 129
# 2022-06-03 21:52:16.096426: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7500 of size 256 next 130
# 2022-06-03 21:52:16.096428: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7600 of size 256 next 131
# 2022-06-03 21:52:16.096430: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7700 of size 256 next 73
# 2022-06-03 21:52:16.096432: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abb7800 of size 40960 next 74
# 2022-06-03 21:52:16.096434: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abc1800 of size 196608 next 19
# 2022-06-03 21:52:16.096436: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67abf1800 of size 196608 next 83
# 2022-06-03 21:52:16.096438: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67ac21800 of size 16384 next 89
# 2022-06-03 21:52:16.096441: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67ac25800 of size 20480 next 91
# 2022-06-03 21:52:16.096443: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67ac2a800 of size 3507968 next 32
# 2022-06-03 21:52:16.096445: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67af82f00 of size 8144640 next 33
# 2022-06-03 21:52:16.096447: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b747600 of size 16384 next 99
# 2022-06-03 21:52:16.096449: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b74b600 of size 20480 next 100
# 2022-06-03 21:52:16.096451: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b750600 of size 20480 next 39
# 2022-06-03 21:52:16.096453: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b755600 of size 15360 next 104
# 2022-06-03 21:52:16.096455: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b759200 of size 40960 next 136
# 2022-06-03 21:52:16.096457: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b763200 of size 20480 next 138
# 2022-06-03 21:52:16.096459: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b768200 of size 196608 next 140
# 2022-06-03 21:52:16.096461: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b798200 of size 196608 next 141
# 2022-06-03 21:52:16.096462: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7c8200 of size 20480 next 142
# 2022-06-03 21:52:16.096464: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7cd200 of size 256 next 144
# 2022-06-03 21:52:16.096466: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7cd300 of size 20480 next 145
# 2022-06-03 21:52:16.096468: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7d2300 of size 256 next 146
# 2022-06-03 21:52:16.096470: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7d2400 of size 20480 next 147
# 2022-06-03 21:52:16.096472: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7d7400 of size 256 next 148
# 2022-06-03 21:52:16.096474: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7d7500 of size 49152 next 149
# 2022-06-03 21:52:16.096476: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7e3500 of size 49152 next 150
# 2022-06-03 21:52:16.096478: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7ef500 of size 20480 next 151
# 2022-06-03 21:52:16.096480: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7f4500 of size 256 next 152
# 2022-06-03 21:52:16.096482: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7f4600 of size 16384 next 153
# 2022-06-03 21:52:16.096484: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7f8600 of size 256 next 154
# 2022-06-03 21:52:16.096486: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7f8700 of size 20480 next 155
# 2022-06-03 21:52:16.096488: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7fd700 of size 256 next 156
# 2022-06-03 21:52:16.096490: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b7fd800 of size 20480 next 157
# 2022-06-03 21:52:16.096492: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b802800 of size 256 next 158
# 2022-06-03 21:52:16.096494: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b802900 of size 15360 next 159
# 2022-06-03 21:52:16.096496: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b806500 of size 256 next 160
# 2022-06-03 21:52:16.096498: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b806600 of size 7680 next 161
# 2022-06-03 21:52:16.096500: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b808400 of size 256 next 162
# 2022-06-03 21:52:16.096502: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b808500 of size 2560 next 163
# 2022-06-03 21:52:16.096504: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b808f00 of size 256 next 164
# 2022-06-03 21:52:16.096506: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809000 of size 256 next 165
# 2022-06-03 21:52:16.096507: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809100 of size 256 next 166
# 2022-06-03 21:52:16.096509: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809200 of size 256 next 167
# 2022-06-03 21:52:16.096511: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809300 of size 256 next 168
# 2022-06-03 21:52:16.096513: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809400 of size 2560 next 169
# 2022-06-03 21:52:16.096515: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809e00 of size 256 next 170
# 2022-06-03 21:52:16.096517: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b809f00 of size 40960 next 171
# 2022-06-03 21:52:16.096519: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b813f00 of size 256 next 172
# 2022-06-03 21:52:16.096521: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b814000 of size 20480 next 173
# 2022-06-03 21:52:16.096523: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b819000 of size 256 next 174
# 2022-06-03 21:52:16.096525: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b819100 of size 196608 next 175
# 2022-06-03 21:52:16.096527: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b849100 of size 196608 next 176
# 2022-06-03 21:52:16.096529: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b879100 of size 20480 next 177
# 2022-06-03 21:52:16.096530: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b87e100 of size 256 next 178
# 2022-06-03 21:52:16.096532: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b87e200 of size 16384 next 179
# 2022-06-03 21:52:16.096534: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b882200 of size 256 next 180
# 2022-06-03 21:52:16.096536: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b882300 of size 20480 next 181
# 2022-06-03 21:52:16.096538: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b887300 of size 256 next 182
# 2022-06-03 21:52:16.096540: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b887400 of size 20480 next 183
# 2022-06-03 21:52:16.096542: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b88c400 of size 256 next 184
# 2022-06-03 21:52:16.096544: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b88c500 of size 49152 next 185
# 2022-06-03 21:52:16.096546: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b898500 of size 49152 next 186
# 2022-06-03 21:52:16.096548: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8a4500 of size 20480 next 187
# 2022-06-03 21:52:16.096550: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8a9500 of size 256 next 188
# 2022-06-03 21:52:16.096552: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8a9600 of size 16384 next 189
# 2022-06-03 21:52:16.096554: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8ad600 of size 256 next 190
# 2022-06-03 21:52:16.096556: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8ad700 of size 20480 next 191
# 2022-06-03 21:52:16.096558: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8b2700 of size 256 next 192
# 2022-06-03 21:52:16.096559: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8b2800 of size 20480 next 193
# 2022-06-03 21:52:16.096561: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8b7800 of size 256 next 194
# 2022-06-03 21:52:16.096563: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8b7900 of size 15360 next 195
# 2022-06-03 21:52:16.096565: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bb500 of size 256 next 196
# 2022-06-03 21:52:16.096567: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bb600 of size 7680 next 197
# 2022-06-03 21:52:16.096569: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bd400 of size 256 next 198
# 2022-06-03 21:52:16.096571: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bd500 of size 2560 next 199
# 2022-06-03 21:52:16.096573: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bdf00 of size 256 next 200
# 2022-06-03 21:52:16.096575: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be000 of size 256 next 201
# 2022-06-03 21:52:16.096577: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be100 of size 256 next 202
# 2022-06-03 21:52:16.096579: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be200 of size 256 next 203
# 2022-06-03 21:52:16.096580: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be300 of size 256 next 204
# 2022-06-03 21:52:16.096582: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be400 of size 256 next 205
# 2022-06-03 21:52:16.096584: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be500 of size 256 next 206
# 2022-06-03 21:52:16.096586: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be600 of size 256 next 207
# 2022-06-03 21:52:16.096588: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be700 of size 256 next 208
# 2022-06-03 21:52:16.096590: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be800 of size 256 next 209
# 2022-06-03 21:52:16.096592: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8be900 of size 256 next 210
# 2022-06-03 21:52:16.096594: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bea00 of size 256 next 211
# 2022-06-03 21:52:16.096596: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8beb00 of size 256 next 212
# 2022-06-03 21:52:16.096597: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bec00 of size 256 next 213
# 2022-06-03 21:52:16.096599: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bed00 of size 256 next 214
# 2022-06-03 21:52:16.096601: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bee00 of size 256 next 215
# 2022-06-03 21:52:16.096603: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 67b8bef00 of size 256 next 236
# 2022-06-03 21:52:16.096605: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bf000 of size 256 next 227
# 2022-06-03 21:52:16.096607: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bf100 of size 256 next 242
# 2022-06-03 21:52:16.096609: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bf200 of size 256 next 241
# 2022-06-03 21:52:16.096611: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 67b8bf300 of size 768 next 261
# 2022-06-03 21:52:16.096613: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bf600 of size 256 next 246
# 2022-06-03 21:52:16.096615: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67b8bf700 of size 256 next 233
# 2022-06-03 21:52:16.096617: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 67b8bf800 of size 2531840 next 35
# 2022-06-03 21:52:16.096619: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67bb29a00 of size 20480 next 29
# 2022-06-03 21:52:16.096621: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67bb2ea00 of size 4051968 next 36
# 2022-06-03 21:52:16.096623: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67bf0be00 of size 8144640 next 37
# 2022-06-03 21:52:16.096625: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 67c6d0500 of size 20232448 next 14
# 2022-06-03 21:52:16.096627: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67da1be00 of size 8123136 next 78
# 2022-06-03 21:52:16.096629: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e1db100 of size 8123136 next 15
# 2022-06-03 21:52:16.096631: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e99a400 of size 256 next 18
# 2022-06-03 21:52:16.096633: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e99a500 of size 256 next 12
# 2022-06-03 21:52:16.096635: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e99a600 of size 256 next 22
# 2022-06-03 21:52:16.096637: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e99a700 of size 256 next 25
# 2022-06-03 21:52:16.096638: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e99a800 of size 256 next 28
# 2022-06-03 21:52:16.096641: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67e99a900 of size 16244992 next 16
# 2022-06-03 21:52:16.096643: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 67f918a00 of size 32492544 next 17
# 2022-06-03 21:52:16.096645: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 681815600 of size 8144896 next 30
# 2022-06-03 21:52:16.096647: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 681fd9e00 of size 256 next 31
# 2022-06-03 21:52:16.096649: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 681fd9f00 of size 40593664 next 20
# 2022-06-03 21:52:16.096651: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 684690800 of size 32492544 next 21
# 2022-06-03 21:52:16.096653: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68658d400 of size 8123136 next 103
# 2022-06-03 21:52:16.096655: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 686d4c700 of size 8123136 next 23
# 2022-06-03 21:52:16.096657: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68750ba00 of size 32492544 next 24
# 2022-06-03 21:52:16.096659: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 689408600 of size 16246272 next 26
# 2022-06-03 21:52:16.096661: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68a386c00 of size 32492544 next 27
# 2022-06-03 21:52:16.096663: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 68c283800 of size 48738816 next 40
# 2022-06-03 21:52:16.096665: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68f0fea00 of size 8123136 next 87
# 2022-06-03 21:52:16.096667: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68f8bdd00 of size 49152 next 13
# 2022-06-03 21:52:16.096669: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68f8c9d00 of size 49152 next 95
# 2022-06-03 21:52:16.096671: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68f8d5d00 of size 20480 next 96
# 2022-06-03 21:52:16.096673: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68f8dad00 of size 2036224 next 98
# 2022-06-03 21:52:16.096675: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68facbf00 of size 256 next 222
# 2022-06-03 21:52:16.096677: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68facc000 of size 256 next 238
# 2022-06-03 21:52:16.096679: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68facc100 of size 256 next 219
# 2022-06-03 21:52:16.096681: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68facc200 of size 256 next 231
# 2022-06-03 21:52:16.096683: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 68facc300 of size 256 next 251
# 2022-06-03 21:52:16.096685: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 68facc400 of size 5966848 next 41
# 2022-06-03 21:52:16.096687: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 69007d000 of size 32492544 next 42
# 2022-06-03 21:52:16.096689: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 691f79c00 of size 8123136 next 113
# 2022-06-03 21:52:16.096691: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 692738f00 of size 8123136 next 44
# 2022-06-03 21:52:16.096693: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 692ef8200 of size 32492544 next 45
# 2022-06-03 21:52:16.096695: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 694df4e00 of size 8123136 next 125
# 2022-06-03 21:52:16.096696: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 6955b4100 of size 8123136 next 47
# 2022-06-03 21:52:16.096698: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 695d73400 of size 32492544 next 48
# 2022-06-03 21:52:16.096700: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 697c70000 of size 16246272 next 50
# 2022-06-03 21:52:16.096702: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 698bee600 of size 32492544 next 51
# 2022-06-03 21:52:16.096704: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 69aaeb200 of size 16246272 next 53
# 2022-06-03 21:52:16.096706: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 69ba69800 of size 32492544 next 54
# 2022-06-03 21:52:16.096708: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 69d966400 of size 16246272 next 56
# 2022-06-03 21:52:16.096710: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 69e8e4a00 of size 32492544 next 57
# 2022-06-03 21:52:16.096712: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 6a07e1600 of size 1109655552 next 264
# 2022-06-03 21:52:16.096714: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 6e2a21600 of size 554827776 next 217
# 2022-06-03 21:52:16.096716: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 703b41600 of size 554827776 next 248
# 2022-06-03 21:52:16.096718: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 724c61600 of size 554827776 next 269
# 2022-06-03 21:52:16.096720: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 745d81600 of size 551414272 next 18446744073709551615
# 2022-06-03 21:52:16.096722: I tensorflow/core/common_runtime/bfc_allocator.cc:1088]      Summary of in-use Chunks by size:
# 2022-06-03 21:52:16.096726: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 131 Chunks of size 256 totalling 32.8KiB
# 2022-06-03 21:52:16.096729: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-06-03 21:52:16.096731: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 5 Chunks of size 2560 totalling 12.5KiB
# 2022-06-03 21:52:16.096734: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 4352 totalling 4.2KiB
# 2022-06-03 21:52:16.096736: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 7680 totalling 22.5KiB
# 2022-06-03 21:52:16.096738: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 15360 totalling 45.0KiB
# 2022-06-03 21:52:16.096741: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 5 Chunks of size 16384 totalling 80.0KiB
# 2022-06-03 21:52:16.096743: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 18432 totalling 18.0KiB
# 2022-06-03 21:52:16.096746: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 21 Chunks of size 20480 totalling 420.0KiB
# 2022-06-03 21:52:16.096748: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 40960 totalling 120.0KiB
# 2022-06-03 21:52:16.096750: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 49152 totalling 288.0KiB
# 2022-06-03 21:52:16.096753: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 196608 totalling 1.12MiB
# 2022-06-03 21:52:16.096755: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 2036224 totalling 1.94MiB
# 2022-06-03 21:52:16.096757: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 3507968 totalling 3.34MiB
# 2022-06-03 21:52:16.096759: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 4051968 totalling 3.86MiB
# 2022-06-03 21:52:16.096761: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 8 Chunks of size 8123136 totalling 61.97MiB
# 2022-06-03 21:52:16.096764: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 8144640 totalling 15.53MiB
# 2022-06-03 21:52:16.096766: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 8144896 totalling 7.77MiB
# 2022-06-03 21:52:16.096768: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 16244992 totalling 15.49MiB
# 2022-06-03 21:52:16.096770: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 16246272 totalling 15.49MiB
# 2022-06-03 21:52:16.096773: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 29097984 totalling 27.75MiB
# 2022-06-03 21:52:16.096775: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 10 Chunks of size 32492544 totalling 309.87MiB
# 2022-06-03 21:52:16.096777: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 58195968 totalling 55.50MiB
# 2022-06-03 21:52:16.096780: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 554827776 totalling 1.55GiB
# 2022-06-03 21:52:16.096782: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 1109655552 totalling 2.07GiB
# 2022-06-03 21:52:16.096784: I tensorflow/core/common_runtime/bfc_allocator.cc:1095] Sum Total of in-use chunks: 4.12GiB
# 2022-06-03 21:52:16.096786: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] total_region_allocated_bytes_: 5710938112 memory_limit_: 5710938112 available bytes: 0 curr_region_allocation_bytes_: 11421876224
# 2022-06-03 21:52:16.096792: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] Stats:
# Limit:                      5710938112
# InUse:                      4429769472
# MaxInUse:                   4984597760
# NumAllocs:                     1236063
# MaxAllocSize:               1109655552
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-06-03 21:52:16.096798: W tensorflow/core/common_runtime/bfc_allocator.cc:491] ***********************************************************************_________***********_________

# %%
modelHP(x_train[0:5])

# %%
modelHP.save("./SavedModels/R2.81/")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./SavedModels/R2.81/assets
# INFO:tensorflow:Assets written to: ./SavedModels/R2.81/assets
