# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np
import healpy as hp
nside=32

# %%
import gc

# %%
import pyccl as ccl

cosmo = ccl.Cosmology(Omega_c = 0.262, Omega_b = 0.048, h = 0.69, sigma8 = 0.83, n_s = 0.96)

# %%
zs=np.linspace(0,1,100)
dNdz = np.ones(zs.shape)
bias = 1*np.ones(len(dNdz))

# %%
clustering = ccl.NumberCountsTracer(cosmo, has_rsd=False, dndz=(zs,dNdz), bias=(zs,bias))
ell = np.arange(0,6144)
cls_clu = ccl.angular_cl(cosmo, clustering, clustering, ell) #Clustering

# %%
plt.xlabel('$l$',fontsize=18)
plt.ylabel('$C_l$',fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.plot(ell, cls_clu, 'k-')
plt.show()

# %%
fakeOverdensity = hp.synfast(cls_clu,nside=nside)
# Out:
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/sphtfunc.py:433: FutureChangeWarning: The order of the input cl's will change in a future release.
# Use new=True keyword to start using the new order.
# See documentation of healpy.synalm.
#   warnings.warn(
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/sphtfunc.py:822: UserWarning: Sigma is 0.000000 arcmin (0.000000 rad)
#   warnings.warn(
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/sphtfunc.py:827: UserWarning: -> fwhm is 0.000000 arcmin
#   warnings.warn(

# %%
hp.mollview(fakeOverdensity)

# %% [markdown]
# # Use kSZ map to get fake kSZ Maps

# %%
kSZMap = hp.read_map("./kSZ_NS_2048_R_2048_P_2560_DV_256.fits")
# Out:
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/fitsfunc.py:368: UserWarning: If you are not specifying the input dtype and using the default np.float64 dtype of read_map(), please consider that it will change in a future version to None as to keep the same dtype of the input file: please explicitly set the dtype if it is important to you.
#   warnings.warn(
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/fitsfunc.py:391: UserWarning: NSIDE = 2048
#   warnings.warn("NSIDE = {0:d}".format(nside))
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/fitsfunc.py:400: UserWarning: ORDERING = RING in fits file
#   warnings.warn("ORDERING = {0:s} in fits file".format(ordering))
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/fitsfunc.py:428: UserWarning: INDXSCHM = IMPLICIT
#   warnings.warn("INDXSCHM = {0:s}".format(schm))

# %%
kSZPowSpec = hp.anafast(kSZMap)

# %%
fakekSZ = hp.synfast(kSZPowSpec,nside=nside)

# %%
hp.mollview(fakekSZ)

# %%
#Need the +1 because a -1 overdensity really means no particles (i.e. overdensity+1 is the value that is directly proportional to mass)
fakeVel = fakekSZ/(fakeOverdensity+1)
plt.hist(fakeVel,bins = np.linspace(-5*10**-6,5*10**-6));

# %%
hp.mollview(fakeVel,min = -5*10**-6,max=5*10**-6)

# %% [markdown]
# # Make 200 fake maps

# %%
from deepsphere import HealpyGCNN
from deepsphere import healpy_layers as hp_layer
from deepsphere import utils

from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import tensorflow_probability as tfp

# %%
import sys

# %%
sizeOfOneSet = 3*sys.getsizeof(fakeVel)/(1*10**9)

# %%
#This is how many data triplets I can fit in memory
25/sizeOfOneSet
# Out:
# 84681.46221174429

# %%
numSets = 10000

overdensData = np.zeros((numSets,12*nside**2))
kSZData = np.zeros((numSets,12*nside**2))
velData = np.zeros((numSets,12*nside**2))

for i in range(0,numSets):
    overdensData[i] = hp.synfast(cls_clu,nside=nside)
    kSZData[i] = hp.synfast(kSZPowSpec,nside=nside)
    velData[i] = kSZData[i]/(overdensData[i]+1)
# Out:
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/sphtfunc.py:433: FutureChangeWarning: The order of the input cl's will change in a future release.
# Use new=True keyword to start using the new order.
# See documentation of healpy.synalm.
#   warnings.warn(
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/sphtfunc.py:822: UserWarning: Sigma is 0.000000 arcmin (0.000000 rad)
#   warnings.warn(
# /home/wurdahl/miniconda3/lib/python3.8/site-packages/healpy/sphtfunc.py:827: UserWarning: -> fwhm is 0.000000 arcmin
#   warnings.warn(

# %%
x_raw = np.stack((overdensData,kSZData),axis=2)
x_raw = np.reshape(x_raw,(numSets,2*12*nside**2))

x_train, x_test = np.split(x_raw, indices_or_sections=[numSets-numSets//10])
y_train, y_test = np.split(velData, indices_or_sections=[numSets-numSets//10])

# %%
del overdensData
del kSZData
del velData
del x_raw
gc.collect()
# Out:
# 22

# %%
dset_test = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_test),
                                 tf.data.Dataset.from_tensor_slices(y_test)))
dset_test = dset_test.batch(50)

dset_train = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_train),
                                  tf.data.Dataset.from_tensor_slices(y_train)))                                
dset_train = dset_train.batch(50)

# %%
del x_test
del y_test
del x_train
del y_train
gc.collect()
# Out:
# 0

# %%
layersMod = [# this is a graph convolutional layer, it preserves the shape of the input
          hp_layer.HealpyChebyshev(K=10, Fout=5, use_bias=True, use_bn=True, 
                                   activation="relu"),
          # another graph convolutional layer, it preserves the shape of the input
          hp_layer.HealpyMonomial(K=10, Fout=5, use_bias=True, use_bn=True, 
                                   activation="relu"),
          # a residual layer using graph convolutions
          hp_layer.Healpy_ResidualLayer(layer_type="CHEBY", 
                                        layer_kwargs={"K": 10, "activation": "relu",
                                                      "use_bn": True, "use_bias": True},
                                        use_bn=False,
                                        activation="relu", alpha=0.1),
          tf.keras.layers.Dense(1, activation="sigmoid"),
          tf.keras.layers.Flatten()
      ]

# %%
tf.keras.backend.clear_session()
modelHP = HealpyGCNN(nside=nside, layers=layersMod,indices=np.arange(0,12*nside**2), n_neighbors=8)
# Out:
# WARNING: This network assumes that everything concerning healpy is in NEST ordering...
# Detected a reduction factor of 1.0, the input with nside 32 will be transformed to 32 during a forward pass. Checking for consistency with indices...
# indices seem consistent...

# %%
padded_pixel = np.arange(0,12*nside**2)
modelHP.build(input_shape=(None, len(padded_pixel), 1))
modelHP.summary(110)
# Out:
# Model: "healpy_gcnn_1"
# ______________________________________________________________________________________________________________
#  Layer (type)                                    Output Shape                                Param #
# ==============================================================================================================
#  chebyshev (Chebyshev)                           (None, 12288, 5)                            65
#
#  monomial (Monomial)                             (None, 12288, 5)                            265
#
#  gcnn__residual_layer (GCNN_ResidualLayer)       (None, 12288, 5)                            530
#
#  dense (Dense)                                   (None, 12288, 1)                            6
#
#  flatten (Flatten)                               (None, 12288)                               0
#
# ==============================================================================================================
# Total params: 866
# Trainable params: 826
# Non-trainable params: 40
# ______________________________________________________________________________________________________________

# %%
model = models.Sequential()
model.add(tf.keras.Input(shape=(2*12*nside**2)))
model.add(tf.keras.layers.Dense(12*nside**2, activation='relu'))
model.add(tf.keras.layers.Dense(12*nside**2, activation='relu'))

# %%
model.build()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12288)             302002176
#
#  dense_1 (Dense)             (None, 12288)             151007232
#
# =================================================================
# Total params: 453,009,408
# Trainable params: 453,009,408
# Non-trainable params: 0
# _________________________________________________________________

# %%
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.Huber(delta=1.0,reduction="auto",name="huber_loss"),
#               metrics=[r_square])

# %%
# history = model.fit(x_train,y_train,epochs=10,validation_data=(x_test, y_test))

# %%
inputs = tf.keras.Input(shape=(2*12*nside**2))
x = model(inputs, training=True)
outputs = modelHP(x)
modelTot = tf.keras.Model(inputs,outputs)

# %%
modelTot.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 24576)]           0
#
#  sequential (Sequential)     (None, 12288)             453009408
#
#  healpy_gcnn_1 (HealpyGCNN)  (None, 12288)             866
#
# =================================================================
# Total params: 453,010,274
# Trainable params: 453,010,234
# Non-trainable params: 40
# _________________________________________________________________

# %%
modelTot.build(input_shape=(None,2*12*nside**2))

# %%
modelTot.compile(optimizer='adam',
              loss=tf.keras.losses.Huber(delta=1.0,reduction="auto",name="huber_loss"),
              metrics=[r_square])

# %%
history = modelTot.fit(dset_train,epochs=25,validation_data=dset_test)
#history = modelTot.fit(dset_train,epochs=25,validation_data=(dset_test))
# Out:
# Epoch 1/25
# 282/282 [==============================] - 401s 1s/step - loss: 0.0869 - r_square: -324011982848.0000 - val_loss: 0.0599 - val_r_square: -220442296320.0000
# Epoch 2/25
# 282/282 [==============================] - 399s 1s/step - loss: 0.0426 - r_square: -158679433216.0000 - val_loss: 0.0282 - val_r_square: -103810367488.0000
# Epoch 3/25
# 282/282 [==============================] - 404s 1s/step - loss: 0.0197 - r_square: -73431703552.0000 - val_loss: 0.0134 - val_r_square: -49338355712.0000
# Epoch 4/25
# 282/282 [==============================] - 402s 1s/step - loss: 0.0093 - r_square: -34542653440.0000 - val_loss: 0.0073 - val_r_square: -26907060224.0000
# Epoch 5/25
# 282/282 [==============================] - 403s 1s/step - loss: 0.0048 - r_square: -17902962688.0000 - val_loss: 0.0036 - val_r_square: -13174638592.0000
# Epoch 6/25
# 282/282 [==============================] - 407s 1s/step - loss: 0.0028 - r_square: -10306752512.0000 - val_loss: 0.0021 - val_r_square: -7789354496.0000
# Epoch 7/25
# 282/282 [==============================] - 401s 1s/step - loss: 0.0017 - r_square: -6494305792.0000 - val_loss: 0.0014 - val_r_square: -5178826240.0000
# Epoch 8/25
# 282/282 [==============================] - 401s 1s/step - loss: 0.0012 - r_square: -4407727616.0000 - val_loss: 0.0010 - val_r_square: -3712693248.0000
# Epoch 9/25
# 282/282 [==============================] - 400s 1s/step - loss: 8.3216e-04 - r_square: -3102810624.0000 - val_loss: 7.0745e-04 - val_r_square: -2601579008.0000
# Epoch 10/25
# 282/282 [==============================] - 400s 1s/step - loss: 5.9463e-04 - r_square: -2216434944.0000 - val_loss: 5.5138e-04 - val_r_square: -2027653504.0000
# Epoch 11/25
# 282/282 [==============================] - 401s 1s/step - loss: 4.4823e-04 - r_square: -1671447680.0000 - val_loss: 4.1037e-04 - val_r_square: -1509106560.0000
# Epoch 12/25
# 282/282 [==============================] - 401s 1s/step - loss: 3.4192e-04 - r_square: -1274567296.0000 - val_loss: 3.0584e-04 - val_r_square: -1124723712.0000
# Epoch 13/25
# 282/282 [==============================] - 400s 1s/step - loss: 2.6527e-04 - r_square: -989195840.0000 - val_loss: 2.7435e-04 - val_r_square: -1008980480.0000
# Epoch 14/25
# 282/282 [==============================] - 401s 1s/step - loss: 2.0830e-04 - r_square: -776760000.0000 - val_loss: 2.2259e-04 - val_r_square: -818622272.0000
# Epoch 15/25
# 282/282 [==============================] - 400s 1s/step - loss: 1.6528e-04 - r_square: -616086016.0000 - val_loss: 1.4654e-04 - val_r_square: -538920576.0000
# Epoch 16/25
# 282/282 [==============================] - 401s 1s/step - loss: 1.3658e-04 - r_square: -509407136.0000 - val_loss: 1.1922e-04 - val_r_square: -438454112.0000
# Epoch 17/25
# 282/282 [==============================] - 400s 1s/step - loss: 8.6550e-05 - r_square: -322552896.0000 - val_loss: 5.0606e-05 - val_r_square: -186107696.0000
# Epoch 18/25
# 282/282 [==============================] - 400s 1s/step - loss: 4.4636e-05 - r_square: -166431088.0000 - val_loss: 3.9877e-05 - val_r_square: -146651184.0000
# Epoch 19/25
# 282/282 [==============================] - 404s 1s/step - loss: 3.4877e-05 - r_square: -129985848.0000 - val_loss: 3.1124e-05 - val_r_square: -114460560.0000
# Epoch 20/25
# 282/282 [==============================] - 401s 1s/step - loss: 2.8029e-05 - r_square: -104558512.0000 - val_loss: 2.5944e-05 - val_r_square: -95410000.0000
# Epoch 21/25
# 282/282 [==============================] - 401s 1s/step - loss: 2.2902e-05 - r_square: -85400272.0000 - val_loss: 2.1107e-05 - val_r_square: -77621472.0000
# Epoch 22/25
# 282/282 [==============================] - 402s 1s/step - loss: 1.8936e-05 - r_square: -70603152.0000 - val_loss: 1.7515e-05 - val_r_square: -64412200.0000
# Epoch 23/25
# 282/282 [==============================] - 401s 1s/step - loss: 1.5706e-05 - r_square: -58580040.0000 - val_loss: 1.5450e-05 - val_r_square: -56819060.0000
# Epoch 24/25
# 282/282 [==============================] - 401s 1s/step - loss: 1.3062e-05 - r_square: -48697796.0000 - val_loss: 1.2222e-05 - val_r_square: -44948056.0000
# Epoch 25/25
# 282/282 [==============================] - 400s 1s/step - loss: 1.0848e-05 - r_square: -40443960.0000 - val_loss: 1.0072e-05 - val_r_square: -37039308.0000

# %%
initial_epochs = 25
fine_tune_epochs = 10
total_epochs =  initial_epochs + fine_tune_epochs

history_further = modelTot.fit(dset_train,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=dset_test)
# Out:
# Epoch 25/35
# 282/282 [==============================] - 401s 1s/step - loss: 9.0441e-06 - r_square: -33721876.0000 - val_loss: 8.3594e-06 - val_r_square: -30741444.0000
# Epoch 26/35
# 282/282 [==============================] - 400s 1s/step - loss: 7.4943e-06 - r_square: -27940048.0000 - val_loss: 6.7925e-06 - val_r_square: -24979558.0000
# Epoch 27/35
# 282/282 [==============================] - 401s 1s/step - loss: 6.0075e-06 - r_square: -22399036.0000 - val_loss: 5.1277e-06 - val_r_square: -18856918.0000
# Epoch 28/35
# 282/282 [==============================] - 402s 1s/step - loss: 4.0077e-06 - r_square: -14931817.0000 - val_loss: 2.9360e-06 - val_r_square: -10796933.0000
# Epoch 29/35
# 282/282 [==============================] - 402s 1s/step - loss: 2.5511e-06 - r_square: -9511508.0000 - val_loss: 1.7588e-06 - val_r_square: -6468066.0000
# Epoch 30/35
# 282/282 [==============================] - 402s 1s/step - loss: 1.6384e-06 - r_square: -6110319.0000 - val_loss: 1.4558e-06 - val_r_square: -5353848.0000
# Epoch 31/35
# 282/282 [==============================] - 402s 1s/step - loss: 1.0721e-06 - r_square: -3995751.5000 - val_loss: 8.6031e-07 - val_r_square: -3163968.0000
# Epoch 32/35
# 282/282 [==============================] - 402s 1s/step - loss: 7.1906e-07 - r_square: -2680752.2500 - val_loss: 5.6890e-07 - val_r_square: -2092242.5000
# Epoch 33/35
# 282/282 [==============================] - 402s 1s/step - loss: 4.9552e-07 - r_square: -1847889.8750 - val_loss: 4.1752e-07 - val_r_square: -1535513.6250
# Epoch 34/35
# 282/282 [==============================] - 403s 1s/step - loss: 3.4820e-07 - r_square: -1298229.7500 - val_loss: 2.9878e-07 - val_r_square: -1098825.3750
# Epoch 35/35
# 282/282 [==============================] - 403s 1s/step - loss: 2.5531e-07 - r_square: -952352.9375 - val_loss: 2.1656e-07 - val_r_square: -796458.5625

# %%
modelTot.save('./SavedModels/baseModel35Epochs/')
# Out:
# INFO:tensorflow:Assets written to: ./SavedModels/baseModel35Epochs/assets

# %%
modelTot = tf.keras.models.load_model('./SavedModels/baseModel35Epochs/',custom_objects={'r_square':r_square})

# %%
layersHP2 = [# this is a graph convolutional layer, it preserves the shape of the input
          hp_layer.HealpyChebyshev(K=10, Fout=10, use_bias=True, use_bn=True, 
                                   activation="relu"),
          # another graph convolutional layer, it preserves the shape of the input
          hp_layer.HealpyMonomial(K=12, Fout=10, use_bias=True, use_bn=True, 
                                   activation="relu"),
          # a residual layer using graph convolutions
          hp_layer.Healpy_ResidualLayer(layer_type="CHEBY", 
                                        layer_kwargs={"K": 10, "activation": "relu",
                                                      "use_bn": True, "use_bias": True},
                                        use_bn=False,
                                        activation="relu", alpha=0.1),
          hp_layer.HealpyChebyshev(K=10, Fout=10, use_bias=True, use_bn=True, 
                                   activation="relu"),
          hp_layer.Healpy_ResidualLayer(layer_type="CHEBY", 
                                        layer_kwargs={"K": 10, "activation": "relu",
                                                      "use_bn": True, "use_bias": True},
                                        use_bn=False,
                                        activation="relu", alpha=0.1),
          hp_layer.HealpyMonomial(K=10, Fout=10, use_bias=True, use_bn=True, 
                                   activation="relu"),
          hp_layer.HealpyChebyshev(K=10, Fout=1, use_bias=True, use_bn=True, 
                                   activation="relu"),
          layers.Flatten()#,
          #f.keras.layers.Dense(12*nside**2,activation='sigmoid')
      ]

# %%
modelHP2 = HealpyGCNN(nside=nside, layers=layersHP2,indices=np.arange(0,12*nside**2), n_neighbors=40)
# Out:
# WARNING: This network assumes that everything concerning healpy is in NEST ordering...
# Detected a reduction factor of 1.0, the input with nside 32 will be transformed to 32 during a forward pass. Checking for consistency with indices...
# indices seem consistent...

# %%
padded_pixel = np.arange(0,12*nside**2)
modelHP2.build(input_shape=(None, len(padded_pixel), 1))
modelHP2.summary()
# Out:
# Model: "healpy_gcnn_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  chebyshev_31 (Chebyshev)    (None, 12288, 10)         130
#
#  monomial_10 (Monomial)      (None, 12288, 10)         1230
#
#  gcnn__residual_layer_10 (GC  (None, 12288, 10)        2060
#  NN_ResidualLayer)
#
#  chebyshev_34 (Chebyshev)    (None, 12288, 10)         1030
#
#  gcnn__residual_layer_11 (GC  (None, 12288, 10)        2060
#  NN_ResidualLayer)
#
#  monomial_11 (Monomial)      (None, 12288, 10)         1030
#
#  chebyshev_37 (Chebyshev)    (None, 12288, 1)          103
#
#  flatten_5 (Flatten)         (None, 12288)             0
#
# =================================================================
# Total params: 7,643
# Trainable params: 7,481
# Non-trainable params: 162
# _________________________________________________________________

# %%
inputs = tf.keras.Input(shape=(2*12*nside**2))
x = modelTot(inputs, training=False)
outputs = modelHP2(x)
modelAddLayers = tf.keras.Model(inputs,outputs)

# %%
modelTot.trainable = False

# %%
modelAddLayers.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 24576)]           0
#
#  model (Functional)          (None, 12288)             453010274
#
#  healpy_gcnn_11 (HealpyGCNN)  (None, 12288)            7643
#
# =================================================================
# Total params: 453,017,917
# Trainable params: 7,481
# Non-trainable params: 453,010,436
# _________________________________________________________________

# %%
modelAddLayers.build(input_shape=(None,2*12*nside**2))

# %%
modelAddLayers.compile(optimizer='adam',
              loss=tf.keras.losses.Huber(delta=1.0,reduction="auto",name="huber_loss"),
              metrics=[r_square])

# %%
AUTOTUNE = tf.data.AUTOTUNE

dset_train = dset_train.prefetch(buffer_size=AUTOTUNE)
dset_test = dset_test.prefetch(buffer_size=AUTOTUNE)

# %%
historyAddLayers = modelAddLayers.fit(dset_train,epochs=25,validation_data=dset_test)
# Out:
# Epoch 1/25
# 180/180 [==============================] - 1392s 8s/step - loss: 3.3539e-07 - r_square: -1507155.5000 - val_loss: 1.8496e-07 - val_r_square: -826210.5625
# Epoch 2/25
# 180/180 [==============================] - 1384s 8s/step - loss: 1.7154e-07 - r_square: -770894.0625 - val_loss: 1.0320e-07 - val_r_square: -461184.0000
# Epoch 3/25
# 180/180 [==============================] - 1385s 8s/step - loss: 1.0154e-07 - r_square: -456329.1875 - val_loss: 6.3451e-08 - val_r_square: -283574.2812
# Epoch 4/25
# 113/180 [=================>............] - ETA: 8:08 - loss: 6.9986e-08 - r_square: -314472.3750
